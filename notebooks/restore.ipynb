# %%
import sys
import tensorflow as tf

sys.path.append("..")
from models import catdog_model_tf
# Out:
# 2025-10-19 16:10:56.902610: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-19 16:10:57.018314: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-19 16:10:59.235869: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
model = catdog_model_tf.create_model()
model.load_weights('../saved_models/tensorflow/catdog_20_epoch.weights.h5')
# Out:
# /home/amaury/repos/ucm-tfg/.venv/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# 2025-10-19 16:11:05.116977: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
catdog_model_tf.predict_image(model, "../data/test_images/gata.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step

# %%
model.save("../saved_models/tensorflow/catdog_20_epoch.keras")
