# %%
import sys
import torch
import tensorflow as tf

sys.path.append("..")
from models import catdog_model_tf
# Out:
# 2025-10-19 16:29:03.207703: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-19 16:29:03.315716: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-19 16:29:05.574596: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
PATH = "../saved_models/tensorflow/catdog_20_epoch.keras"
model = tf.keras.models.load_model(PATH)
# Out:
# 2025-10-19 16:29:06.699962: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
catdog_model_tf.predict_image(model, "../data/PetImages/Dog/7117.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# [[1.5724985e-18 1.0000000e+00]]
# tf.Tensor([[0.26894143 0.7310586 ]], shape=(1, 2), dtype=float32)
# 2025-10-19 16:29:07.196879: W tensorflow/core/framework/op_kernel.cc:1855] OP_REQUIRES failed at strided_slice_op.cc:117 : INVALID_ARGUMENT: slice index 1 of dimension 0 out of bounds.
# 2025-10-19 16:29:07.196959: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: INVALID_ARGUMENT: slice index 1 of dimension 0 out of bounds.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 catdog_model_tf.predict_image(model, "../data/PetImages/Dog/7117.jpg")
#
# File ~/repos/ucm-tfg/notebooks/../models/catdog_model_tf.py:59, in predict_image(model, path)
#      56 predicted = np.argmax(probs)
#      58 plt.imshow(img)
# ...
