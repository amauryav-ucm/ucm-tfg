# %%
import sys
import torch
import tensorflow as tf

sys.path.append("..")
from models.catdog_model_tf import Model
# Out:
# 2025-10-19 00:13:18.689090: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-19 00:13:18.788486: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-19 00:13:20.672358: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
PATH = "../saved_models/tensorflow/catdog_20_epoch.keras"
model = tf.keras.models.load_model(PATH)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/repos/ucm-tfg/.venv/lib/python3.12/site-packages/keras/src/saving/serialization_lib.py:733, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     732 try:
# --> 733     instance = cls.from_config(inner_config)
#     734 except TypeError as e:
#
# File ~/repos/ucm-tfg/notebooks/../models/catdog_model_tf.py:45, in Model.from_config(cls, config)
#      43 @classmethod
#      44 def from_config(cls, config):
# ---> 45     return cls(build_model=False, **config)
#
# File ~/repos/ucm-tfg/notebooks/../models/catdog_model_tf.py:31, in Model.__init__(self, build_model, **kwargs)
#      30 def __init__(self, build_model=True, **kwargs):
# ---> 31     super().__init__(**kwargs)
#      32     if build_model:
#
# TypeError: Sequential.__init__() got an unexpected keyword argument 'dtype'
#
# ...
